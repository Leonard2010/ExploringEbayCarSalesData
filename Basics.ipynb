# %% [markdown]
# # Exploring Ebay Car Sales Data

# %%
import pandas as pd
import numpy as np

# %%
autos = pd.read_csv("autos.csv", encoding='Latin-1')

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
#changing the dataframe columns from camelcase to the default snakecase in python

# %%
col = ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
       'vehicle_type', 'registration_year', 'gearbox', 'power_PS', 'model',
       'odometer', 'registration_month', 'fuel_type', 'brand',
       'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
       'last_seen']

autos.columns = col

# %%
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_PS', 'model',
#        'odometer', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %%
autos.head(2)
# Out:
#           date_crawled                                        name  seller  \
# 0  2016-03-26 17:47:46            Peugeot_807_160_NAVTECH_ON_BOARD  privat
# 1  2016-04-04 13:38:56  BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik  privat
#
#   offer_type   price   abtest vehicle_type  registration_year    gearbox  \
# 0    Angebot  $5,000  control          bus               2004    manuell
# 1    Angebot  $8,500  control    limousine               1997  automatik
#
#    power_PS   model   odometer  registration_month fuel_type    brand  \
# 0       158  andere  150,000km                   3       lpg  peugeot
# 1       286     7er  150,000km                   6    benzin      bmw
#
#   unrepaired_damage           ad_created  nr_of_pictures  postal_code  \
# 0              nein  2016-03-26 00:00:00               0        79588
# 1              nein  2016-04-04 00:00:00               0        71034
#
#              last_seen
# 0  2016-04-06 06:45:54
# 1  2016-04-06 14:45:08

# %%
autos.describe(include='all')
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-23 18:39:34  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year  gearbox      power_PS  model  \
# ...

# %%
autos['price'].head()
# Out:
# 0    $5,000
# 1    $8,500
# 2    $8,990
# 3    $4,350
# 4    $1,350
# Name: price, dtype: object

# %%
autos['odometer'].head()
# Out:
# 0    150,000km
# 1    150,000km
# 2     70,000km
# 3     70,000km
# 4    150,000km
# Name: odometer, dtype: object

# %%
autos['price'].isnull().value_counts()
# Out:
# False    50000
# Name: price, dtype: int64

# %%
autos['price'] = autos['price'].str.replace('$','')

# %%
autos['price'] = autos['price'].str.replace(',','')

# %%
autos['price'].head()
# Out:
# 0    5000
# 1    8500
# 2    8990
# 3    4350
# 4    1350
# Name: price, dtype: object

# %%
autos['price'] = autos.price.astype(float)

# %%
autos['odometer'].isnull().value_counts()
# Out:
# False    50000
# Name: odometer, dtype: int64

# %%
autos['odometer'].head()
# Out:
# 0    150,000km
# 1    150,000km
# 2     70,000km
# 3     70,000km
# 4    150,000km
# Name: odometer, dtype: object

# %%
autos['odometer'] = autos['odometer'].str.replace(',','')
autos['odometer'] = autos['odometer'].str.replace('km',',').str.strip(',')

# %%
autos['odometer'] = autos['odometer'].astype(float)
autos.odometer.head()
# Out:
# 0    150000.0
# 1    150000.0
# 2     70000.0
# 3     70000.0
# 4    150000.0
# Name: odometer, dtype: float64

# %%
autos = autos.rename({"odometer":"odometer_km"}, axis='columns')

# %%
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_PS', 'model',
#        'odometer_km', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %%
autos['odometer_km'].unique().shape
# Out:
# (13,)

# %%
autos['odometer_km'].describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
autos['odometer_km'].value_counts().head()
# Out:
# 150000.0    32424
# 125000.0     5170
# 100000.0     2169
# 90000.0      1757
# 80000.0      1436
# Name: odometer_km, dtype: int64

# %%
autos['odometer_km'].value_counts().sort_index(ascending=True).head()
# Out:
# 5000.0     967
# 10000.0    264
# 20000.0    784
# 30000.0    789
# 40000.0    819
# Name: odometer_km, dtype: int64

# %%
autos['price'].unique().shape
# Out:
# (2357,)

# %%
autos['price'].describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
autos['price'].head()
# Out:
# 0    5000.0
# 1    8500.0
# 2    8990.0
# 3    4350.0
# 4    1350.0
# Name: price, dtype: float64

# %%
autos[(autos['price'].between(1100.0,7200.0))]
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 12     2016-03-31 19:48:22  Smart_smart_fortwo_coupe_softouch_pure_MHD_Pan...
# 13     2016-03-23 10:48:32                                 Audi_A3_1.6_tuning
# 14     2016-03-23 11:50:46  Renault_Clio_3__Dynamique_1.2__16_V;_viele_Ver...
# 17     2016-03-29 11:46:22                          Volkswagen_Scirocco_2_G60
# 19     2016-03-17 13:36:21        mazda_tribute_2.0_mit_gas_und_tuev_neu_2018
# 20     2016-03-05 19:57:31  Audi_A4_Avant_1.9_TDI_*6_Gang*AHK*Klimatronik*...
# 28     2016-03-19 21:56:19                                      MINI_Cooper_D
# ...

# %% [markdown]
# The new prices after outlier removal

# %%
autos['price'].describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
autos['registration_year'].describe()
# Out:
# count    50000.000000
# mean      2005.073280
# std        105.712813
# min       1000.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %%
autos['registration_year'].value_counts().sort_index(ascending=False).head()
# Out:
# 9999    4
# 9996    1
# 9000    2
# 8888    1
# 6200    1
# Name: registration_year, dtype: int64

# %%
autos['registration_year'].loc[9999]
# Out:
# 2002

# %%
autos['registration_year'].value_counts(normalize=True).sort_index(ascending=False)
# Out:
# 9999    0.00008
# 9996    0.00002
# 9000    0.00004
# 8888    0.00002
# 6200    0.00002
# 5911    0.00002
# 5000    0.00008
# 4800    0.00002
# 4500    0.00002
# 4100    0.00002
# 2800    0.00002
# 2019    0.00006
# 2018    0.00984
# 2017    0.02906
# 2016    0.02632
# 2015    0.00798
# 2014    0.01332
# 2013    0.01612
# 2012    0.02646
# 2011    0.03268
# 2010    0.03194
# 2009    0.04196
# 2008    0.04462
# 2007    0.04608
# 2006    0.05416
# 2005    0.06030
# 2004    0.05474
# 2003    0.05454
# 2002    0.05066
# 2001    0.05406
#          ...
# 1963    0.00018
# 1962    0.00008
# 1961    0.00012
# 1960    0.00068
# 1959    0.00014
# 1958    0.00008
# 1957    0.00004
# 1956    0.00010
# 1955    0.00004
# 1954    0.00004
# 1953    0.00002
# 1952    0.00002
# 1951    0.00004
# 1950    0.00006
# 1948    0.00002
# 1943    0.00002
# 1941    0.00004
# 1939    0.00002
# 1938    0.00002
# 1937    0.00008
# 1934    0.00004
# 1931    0.00002
# 1929    0.00002
# 1927    0.00002
# ...

# %% [markdown]
# Taking a look at the registration_year column, the upper limit is 2016 and the lower limit is chosen as 1960. 1960 was chosen because there are just a few data points below that and some lower years like 1000 are not feasible.

# %%
autos = autos[autos['registration_year'].between(1960,2016)]

# %%
autos.registration_year.describe()
# Out:
# count    47975.000000
# mean      2002.870036
# std          7.012137
# min       1960.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       2016.000000
# Name: registration_year, dtype: float64

# %%
autos['brand'].value_counts()[:20]
# Out:
# volkswagen        10186
# bmw                5283
# opel               5191
# mercedes_benz      4572
# audi               4149
# ford               3346
# renault            2273
# peugeot            1418
# fiat               1242
# seat                872
# skoda               769
# mazda               727
# nissan              725
# citroen             668
# smart               668
# toyota              599
# sonstige_autos      505
# hyundai             473
# volvo               443
# mini                415
# Name: brand, dtype: int64

# %%
brand_considered = list(autos['brand'].value_counts()[:20].index)

# %%
brand_considered
# Out:
# ['volkswagen',
#  'bmw',
#  'opel',
#  'mercedes_benz',
#  'audi',
#  'ford',
#  'renault',
#  'peugeot',
#  'fiat',
#  'seat',
#  'skoda',
#  'mazda',
#  'nissan',
#  'citroen',
#  'smart',
#  'toyota',
#  'sonstige_autos',
#  'hyundai',
#  'volvo',
#  'mini']
